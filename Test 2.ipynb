# %%
import pandas as pd
from openai import OpenAI
import json
import re

# ---------- Directly use API Key ----------
api_key = "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"   # ⚠️ Replace with your actual key securely
client = OpenAI(api_key=api_key)

# ---------- System Prompt for Evaluation ----------
sys_prompt = """
You are an expert evaluator. School students are submitting their problem statements and proposed solutions.  
Your task is to carefully read the problem and solution, then assign **realistic, not inflated scores**.  
Use the examples as calibration and avoid giving 9–10 unless the idea is truly exceptional.

---

### 1. Novelty (Originality)
- 1–2: Very common or generic. Already seen many times.
- 3–4: Slightly inspired but still unoriginal.
- 5–6: Somewhat novel, a bit unique but still familiar.
- 7–8: Creative twist or new angle, but not groundbreaking.
- 9–10: Extremely rare, highly innovative, outstanding originality (very rare).

---

### 2. Usefulness (Problem-Solving Value)
- 1–2: Not useful or irrelevant.
- 3–4: Weak usefulness, doesn’t really solve the problem.
- 5–6: Moderately useful but leaves big gaps.
- 7–8: Strongly useful, solves the problem for most users.
- 9–10: Extremely impactful, very strong real-world value (rare).

---

### 3. Feasibility (Practical Implementation)
- 1–2: Unrealistic, nearly impossible.
- 3–4: Very difficult or costly.
- 5–6: Achievable but resource-heavy or impractical for students.
- 7–8: Feasible with available tech/resources.
- 9–10: Very easy, cheap, and realistic to implement (rare).

---

### 4. Scalability & Impact (Breadth of Benefit)
- 1–2: Not scalable at all.
- 3–4: Very niche, helps only a few.
- 5–6: Somewhat scalable to a community.
- 7–8: Can impact a larger group/region.
- 9–10: Global potential (very rare).

---

### 5. Sustainability (Long-Term & Eco-Friendliness)
- 1–2: Not sustainable, harmful.
- 3–4: Weak sustainability, short-term only.
- 5–6: Moderately sustainable but has concerns.
- 7–8: Good long-term potential, eco-friendly.
- 9–10: Highly sustainable, eco-friendly, long-lasting (rare).

---

⚠️ Rules:
- Be strict. Scores **1–6 should be common**, 7–8 less frequent, 9–10 extremely rare.
- If the solution is unclear, incomplete, or unrealistic, push scores toward 1–3.
- Return ONLY valid JSON with these keys:
  Novelty_Score, Usefulness_Score, Feasibility_Score, Scalability_Score, Sustainability_Score, Evaluators_Count

Example JSON:
{
  "Novelty_Score": 5.0,
  "Usefulness_Score": 4.5,
  "Feasibility_Score": 3.0,
  "Scalability_Score": 4.0,
  "Sustainability_Score": 5.0,
  "Evaluators_Count": 2
}
"""

# ---------- Input Prompt ----------
input_prompt = """
Problems: "The roads of INDIA are polluted by waste materials."
Solutions: "The municipal workers can do to carry the.
Aim : RDCV
Materials:1) vaccum rover 
2)mother board 
3)solar 12v5mage
4)foam sheet
5)Gear motor 
6)mini gear motor.
7)buzzer
8)female adopter
9)camera
10)bluetooth sensor.
etc...

Procedure: 
•first remove the top of vaccum 
•and blick the remote sensor.
•activate the and connect the oter sensor.
•fit the bluetooth camera 
•abd connect to the police satation for the safty purpose.
"
"""
# ---------- API Call ----------
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": sys_prompt},
        {"role": "user", "content": input_prompt},
    ],
    temperature=0,
    max_tokens=300,
)

raw_output = response.choices[0].message.content.strip()

# ---------- Extract JSON ----------
def extract_json(s: str):
    m = re.search(r"\{.*\}", s, flags=re.DOTALL)
    if not m:
        raise ValueError("No JSON object found in model output.")
    return json.loads(m.group(0))

scores = extract_json(raw_output)

# ---------- Print JSON ----------
print(json.dumps(scores, indent=2))
# Out:
# {
#   "Novelty_Score": 3.0,
#   "Usefulness_Score": 4.0,
#   "Feasibility_Score": 4.0,
#   "Scalability_Score": 3.0,
#   "Sustainability_Score": 3.0,
#   "Evaluators_Count": 1
# }

# %%
import pandas as pd
from openai import OpenAI
import json
import re

# ---------- Directly use API Key ----------
api_key = "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"   # ⚠️ Replace with your actual key securely
client = OpenAI(api_key=api_key)

# ---------- Updated System Prompt for Evaluation ----------
sys_prompt = """
You are an expert evaluator. School students are submitting their problem statements and proposed solutions.  
Your task is to carefully read the problem and solution, then assign **realistic, not inflated scores** according to the rubric below.  

---

1. Novelty (Very Strict Scoring)

1–2: Problem/solution is copied, generic, or minimally adapted from textbooks, internet, or widely known sources. Even a small amount of originality is not enough.

3–4: Problem/solution shows some modification of known ideas but still lacks real innovation. Creativity is weak and mostly derivative.

5–6: Problem is based on students’ own surroundings or observations, but the solution is fairly predictable and not very innovative.

7–8: Problem may be common, but the solution is clearly original, showing strong independent thinking not found in standard references.

9–10: Problem and solution are exceptionally original and rare, demonstrating highly creative, independent, and novel thinking.
---
⚠️ Rules:
- Start scoring in the mid-range (5–6).  
- Push scores down if unclear, impractical, or copied.  
- Only move up for strong originality, impact, or feasibility.  
- 9–10 must be *exceptional and rare*.  

Return ONLY valid JSON with these keys:  
Novelty_Score, Usefulness_Score, Feasibility_Score, Scalability_Score, Sustainability_Score, Evaluators_Count  

Example JSON:
{
  "Novelty_Score": 5.0,
}
"""

# ---------- Input Prompt ----------
input_prompt = """
Problems: "The roads of INDIA are polluted by waste materials."
Solutions: "The municipal workers can do to carry the.
Aim : RDCV
Materials:1) vaccum rover 
2)mother board 
3)solar 12v5mage
4)foam sheet
5)Gear motor 
6)mini gear motor.
7)buzzer
8)female adopter
9)camera
10)bluetooth sensor.
etc...

Procedure: 
•first remove the top of vaccum 
•and blick the remote sensor.
•activate the and connect the oter sensor.
•fit the bluetooth camera 
•abd connect to the police satation for the safty purpose.
"
"""

# ---------- API Call ----------
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": sys_prompt},
        {"role": "user", "content": input_prompt},
    ],
    temperature=0,
    max_tokens=300,
)

raw_output = response.choices[0].message.content.strip()

# ---------- Extract JSON ----------
def extract_json(s: str):
    m = re.search(r"\{.*\}", s, flags=re.DOTALL)
    if not m:
        raise ValueError("No JSON object found in model output.")
    return json.loads(m.group(0))

scores = extract_json(raw_output)

# ---------- Print JSON ----------
print(json.dumps(scores, indent=2))
# Out:
# {
#   "Novelty_Score": 4.0,
#   "Usefulness_Score": 5.0,
#   "Feasibility_Score": 4.0,
#   "Scalability_Score": 3.0,
#   "Sustainability_Score": 4.0,
#   "Evaluators_Count": 1
# }

# %%
import os
import pandas as pd
from openai import OpenAI
import json
import re

# ---------- Secure API Key ----------
# (Better to load from environment for safety)
api_key = os.getenv("OPENAI_API_KEY", "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" )
client = OpenAI(api_key=api_key)

# ---------- Updated System Prompt for Evaluation ----------
sys_prompt = """
You are an expert evaluator. School students are submitting their problem statements and proposed solutions.  
Your task is to carefully read the problem and solution, then assign **realistic, not inflated scores** according to the rubric below.  

---

1. Novelty (Very Strict Scoring)

1–2: Problem/solution is copied, generic, or minimally adapted from textbooks, internet, or widely known sources. Even a small amount of originality is not enough.

3–4: Problem/solution shows some modification of known ideas but still lacks real innovation. Creativity is weak and mostly derivative.

5–6: Problem is based on students’ own surroundings or observations, but the solution is fairly predictable and not very innovative.

7–8: Problem may be common, but the solution is clearly original, showing strong independent thinking not found in standard references.

9–10: Problem and solution are exceptionally original and rare, demonstrating highly creative, independent, and novel thinking.
---
⚠️ Rules:
- Start scoring in the mid-range (5–6).  
- Push scores down if unclear, impractical, or copied.  
- Only move up for strong originality, impact, or feasibility.  
- 9–10 must be *exceptional and rare*.  

Return ONLY valid JSON with this key:  
Novelty_Score  

Example JSON:
{
  "Novelty_Score": 5.0
}
"""

# ---------- Input Prompt ----------
input_prompt = """
Problems: "The roads of INDIA are polluted by waste materials."
Solutions: "The municipal workers can do to carry the.
Aim : RDCV
Materials:1) vaccum rover 
2)mother board 
3)solar 12v5mage
4)foam sheet
5)Gear motor 
6)mini gear motor.
7)buzzer
8)female adopter
9)camera
10)bluetooth sensor.
etc...

Procedure: 
•first remove the top of vaccum 
•and blick the remote sensor.
•activate the and connect the oter sensor.
•fit the bluetooth camera 
•abd connect to the police satation for the safty purpose.
"
"""

# ---------- API Call ----------
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": sys_prompt},
        {"role": "user", "content": input_prompt},
    ],
    temperature=0,
    max_tokens=150,
)

raw_output = response.choices[0].message.content.strip()

# ---------- Extract JSON ----------
def extract_json(s: str):
    m = re.search(r"\{.*\}", s, flags=re.DOTALL)
    if not m:
        raise ValueError("No JSON object found in model output.")
    return json.loads(m.group(0))

score = extract_json(raw_output)

# ---------- Print ONLY Novelty_Score ----------
print(json.dumps({"Novelty_Score": score.get("Novelty_Score")}, indent=2))
# Out:
# {
#   "Novelty_Score": 4.0
# }
